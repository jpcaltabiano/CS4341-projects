# %%
# %%capture
import sys
from collections import Counter
sys.path.insert(0, '../../bomberman')
sys.path.insert(1, '..')
import pygame
import random
from game import Game
from monsters.stupid_monster import StupidMonster
from monsters.selfpreserving_monster import SelfPreservingMonster
sys.path.insert(1, '../groupNN')
from approxqcharacter import ApproxQCharacter
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import time
random.seed(time.time()) # TODO Change this if you want different random choices

# %%
# %%capture
ev_history = pd.DataFrame(columns=['death_bomb', 'death_monster', 'exited'])
ws_history = pd.DataFrame(columns=['exit-distance', 'monster-distance', 'explosion-distance'])
dbsum, dmsum, esum = 0, 0, 0
total = 0
weights = Counter()
# weights = Counter({'exit-distance': -28657.344739297438, 'monster-distance': -82137.49278128003})
# weights = Counter({'monster-distance': -58236.996651541864, 'exit-distance': 515970.36564830824})
epochs = 100
startedutc = time.time()
for i in range(0, epochs):
    start_time = time.time()
    
    if i % 10 == 0: print(f'{epochs - i} epochs left')
    
    g = Game.fromfile('map.txt')
    g.add_monster(StupidMonster("stupid", "S", 3, 5))
    g.add_monster(SelfPreservingMonster("aggressive", "A", 3, 13, 2))

    ours = ApproxQCharacter("me", "C", 0, 0)
    ours.weights = weights
    g.add_character(ours)

#     g.go(1)
#     colorama.init(autoreset=True)
#     self.display_gui()
#     g.draw()
    while not g.done():
        
        (g.world, g.events) = g.world.next()
#         self.display_gui()
#         g.draw()
        g.world.next_decisions()
        for e in g.world.events:
#             print(e, e.tpe)
            if e.tpe == 2: dbsum += 1
            if e.tpe == 3: dmsum += 1
            if e.tpe == 4: esum += 1
#     colorama.deinit()

    weights = ours.weights

    ev_history = ev_history.append({'death_bomb':dbsum, 'death_monster':dmsum, 'exited':esum}, ignore_index=True)
    ws_history = ws_history.append({'exit-distance':ours.weights['exit-distance'], 'monster-distance':ours.weights['monster-distance'], 'explosion-distance':ours.weights['explosion-distance']}, ignore_index=True)
    end_time = time.time()
    total += end_time - start_time
    avg = total / (i+1)
    print(f"Epoch {i + 1} completed in {round((end_time - start_time), 3)} s, avgerage: {round(avg, 3)} s, \
est. time left: {round((((avg * epochs) - (time.time() - startedutc)) / 60), 3)} m")
# Out:
# 100 epochs left
# 6
# 7
# 7
# 8
# 9
# 10
# 10
# 10
# 10
# 11
# 10
# 10
# Epoch 1 completed in 2.811 s, avgerage: 2.811 s, est. time left: 4.639 m
# 6
# 6
# 5
# 6
# 6
# 6
# 5
# 6
# 6
# 7
# 6
# 5
# Epoch 2 completed in 2.626 s, avgerage: 2.718 s, est. time left: 4.44 m
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 7
# 7
# 6
# 6
# 5
# Epoch 3 completed in 2.507 s, avgerage: 2.648 s, est. time left: 4.281 m
# 6
# 6
# 5
# 5
# 6
# 7
# 6
# 5
# 6
# 7
# 6
# 7
# Epoch 4 completed in 2.628 s, avgerage: 2.643 s, est. time left: 4.229 m
# 6
# 5
# 4
# 5
# 6
# 7
# 7
# 8
# 7
# 7
# 6
# 6
# Epoch 5 completed in 2.651 s, avgerage: 2.645 s, est. time left: 4.187 m
# 6
# 7
# 6
# 6
# 7
# 7
# 6
# 7
# 8
# 7
# 8
# 9
# Epoch 6 completed in 3.196 s, avgerage: 2.736 s, est. time left: 4.287 m
# 6
# 7
# 7
# 8
# 7
# 6
# 7
# 7
# 6
# 5
# 5
# 6
# 7
# Epoch 7 completed in 2.116 s, avgerage: 2.648 s, est. time left: 4.104 m
# 6
# 7
# 8
# 7
# 8
# 8
# 8
# 9
# 9
# 8
# 7
# 8
# Epoch 8 completed in 2.779 s, avgerage: 2.664 s, est. time left: 4.085 m
# 6
# 6
# 7
# 6
# 7
# 7
# 6
# 6
# 6
# 5
# 6
# 5
# Epoch 9 completed in 2.613 s, avgerage: 2.659 s, est. time left: 4.032 m
# 6
# 5
# 4
# 5
# 4
# 5
# 5
# 4
# 5
# 5
# 4
# 3
# 3
# Epoch 10 completed in 1.969 s, avgerage: 2.59 s, est. time left: 3.884 m
# 90 epochs left
# 6
# 6
# 6
# 7
# 6
# 7
# 8
# 7
# 7
# 8
# 7
# 8
# Epoch 11 completed in 2.499 s, avgerage: 2.581 s, est. time left: 3.829 m
# 6
# 7
# 8
# 7
# 6
# 5
# 6
# 5
# 5
# 6
# 7
# 7
# Epoch 12 completed in 2.614 s, avgerage: 2.584 s, est. time left: 3.79 m
# 6
# 6
# 7
# 7
# 8
# 7
# 7
# 7
# 7
# 6
# 6
# 7
# Epoch 13 completed in 2.641 s, avgerage: 2.589 s, est. time left: 3.753 m
# 6
# 7
# 7
# 6
# 5
# 6
# 5
# 6
# 7
# 7
# 8
# 7
# Epoch 14 completed in 2.653 s, avgerage: 2.593 s, est. time left: 3.717 m
# 6
# 7
# 8
# 9
# 9
# 8
# 8
# 8
# 8
# 7
# 8
# 8
# Epoch 15 completed in 2.775 s, avgerage: 2.605 s, est. time left: 3.691 m
# 6
# 7
# 7
# 6
# 7
# 7
# 6
# 6
# 7
# 7
# 8
# 7
# Epoch 16 completed in 2.563 s, avgerage: 2.603 s, est. time left: 3.644 m
# 6
# 6
# 6
# 6
# 7
# 8
# 9
# 10
# 11
# 11
# 12
# 12
# Epoch 17 completed in 2.933 s, avgerage: 2.622 s, est. time left: 3.627 m
# 6
# 7
# 7
# 8
# 7
# 6
# 7
# 7
# 6
# 5
# 6
# 5
# Epoch 18 completed in 2.662 s, avgerage: 2.624 s, est. time left: 3.586 m
# 6
# 5
# 5
# 6
# 6
# 7
# 7
# 7
# 7
# 7
# 6
# 5
# Epoch 19 completed in 2.631 s, avgerage: 2.625 s, est. time left: 3.543 m
# 6
# 7
# 7
# 8
# 7
# 7
# 8
# 7
# 8
# 9
# 9
# 9
# Epoch 20 completed in 2.857 s, avgerage: 2.636 s, est. time left: 3.515 m
# 80 epochs left
# 6
# 7
# 7
# 7
# 7
# 7
# 6
# 7
# 7
# 7
# 7
# 6
# Epoch 21 completed in 2.767 s, avgerage: 2.642 s, est. time left: 3.479 m
# 6
# 5
# 5
# 7
# 6
# 6
# 6
# 7
# 8
# 8
# 8
# 7
# Epoch 22 completed in 3.035 s, avgerage: 2.66 s, est. time left: 3.458 m
# 6
# 7
# 6
# 6
# 6
# 7
# 6
# 7
# 7
# 7
# 7
# 7
# Epoch 23 completed in 2.824 s, avgerage: 2.667 s, est. time left: 3.423 m
# 6
# 7
# 6
# 7
# 6
# 5
# 6
# 6
# 6
# 7
# 8
# 7
# Epoch 24 completed in 2.844 s, avgerage: 2.675 s, est. time left: 3.388 m
# 6
# 5
# 5
# 4
# 4
# 5
# 4
# 6
# 5
# 6
# 5
# 4
# Epoch 25 completed in 2.621 s, avgerage: 2.673 s, est. time left: 3.341 m
# 6
# 6
# 7
# 8
# 7
# 8
# 8
# 9
# 9
# 9
# 10
# 11
# Epoch 26 completed in 2.906 s, avgerage: 2.682 s, est. time left: 3.307 m
# 6
# 7
# 6
# 7
# 6
# 6
# 6
# 5
# 5
# 5
# 4
# 5
# Epoch 27 completed in 2.726 s, avgerage: 2.683 s, est. time left: 3.265 m
# 6
# 5
# 6
# 5
# 6
# 6
# 7
# 7
# 7
# 8
# 7
# 8
# Epoch 28 completed in 2.902 s, avgerage: 2.691 s, est. time left: 3.229 m
# 6
# 6
# 7
# 6
# 7
# 8
# 8
# 7
# 8
# 9
# 8
# 9
# Epoch 29 completed in 2.902 s, avgerage: 2.698 s, est. time left: 3.193 m
# 6
# 6
# 6
# 7
# 8
# 8
# 8
# 8
# 9
# 10
# 10
# 9
# Epoch 30 completed in 2.701 s, avgerage: 2.698 s, est. time left: 3.148 m
# 70 epochs left
# 6
# 6
# 5
# 5
# 4
# 5
# 4
# 5
# 6
# 7
# 6
# 6
# Epoch 31 completed in 2.518 s, avgerage: 2.693 s, est. time left: 3.096 m
# 6
# 6
# 7
# 8
# 8
# 7
# 7
# 7
# 6
# 7
# 6
# 6
# Epoch 32 completed in 2.826 s, avgerage: 2.697 s, est. time left: 3.056 m
# 6
# 6
# 7
# 6
# 6
# 7
# 7
# 6
# 6
# 5
# 6
# 6
# Epoch 33 completed in 2.684 s, avgerage: 2.696 s, est. time left: 3.011 m
# 6
# 6
# 5
# 5
# 4
# 5
# 6
# 5
# 6
# 7
# 7
# 6
# Epoch 34 completed in 2.526 s, avgerage: 2.691 s, est. time left: 2.96 m
# 6
# 5
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 5
# 5
# 6
# Epoch 35 completed in 2.747 s, avgerage: 2.693 s, est. time left: 2.917 m
# 6
# 6
# 5
# 6
# 7
# 8
# 8
# 6
# 8
# 7
# 6
# 7
# Epoch 36 completed in 2.751 s, avgerage: 2.695 s, est. time left: 2.874 m
# 6
# 7
# 8
# 9
# 9
# 10
# 10
# 11
# 11
# 10
# 11
# 10
# Epoch 37 completed in 3.213 s, avgerage: 2.709 s, est. time left: 2.844 m
# 6
# 5
# 6
# 6
# 6
# 6
# 5
# 5
# 5
# 5
# 6
# 6
# Epoch 38 completed in 2.64 s, avgerage: 2.707 s, est. time left: 2.797 m
# 6
# 6
# 6
# 6
# 7
# 8
# 7
# 8
# 8
# 7
# 6
# 5
# Epoch 39 completed in 2.679 s, avgerage: 2.706 s, est. time left: 2.751 m
# 6
# 6
# 6
# 7
# 7
# 7
# 6
# 6
# 5
# 6
# 6
# 4
# Epoch 40 completed in 2.33 s, avgerage: 2.697 s, est. time left: 2.697 m
# 60 epochs left
# 6
# 7
# 6
# 5
# 5
# 6
# 6
# 5
# 6
# 6
# 7
# 8
# Epoch 41 completed in 2.784 s, avgerage: 2.699 s, est. time left: 2.654 m
# 6
# 7
# 8
# 7
# 7
# 8
# 7
# 8
# 7
# 8
# 7
# 7
# Epoch 42 completed in 2.789 s, avgerage: 2.701 s, est. time left: 2.611 m
# 6
# 7
# 8
# 8
# 8
# 9
# 8
# 9
# 9
# 9
# 10
# 11
# Epoch 43 completed in 2.886 s, avgerage: 2.705 s, est. time left: 2.57 m
# 6
# 6
# 5
# 6
# 7
# 8
# 8
# 7
# 7
# 8
# 7
# 5
# Epoch 44 completed in 2.698 s, avgerage: 2.705 s, est. time left: 2.525 m
# 6
# 7
# 8
# 7
# 6
# 6
# 6
# 6
# 7
# 7
# 7
# 7
# Epoch 45 completed in 2.886 s, avgerage: 2.709 s, est. time left: 2.483 m
# 6
# 7
# 6
# 5
# 5
# 6
# 6
# 6
# 7
# 7
# 6
# 7
# Epoch 46 completed in 3.288 s, avgerage: 2.722 s, est. time left: 2.449 m
# 6
# 7
# 6
# 6
# 7
# 6
# 7
# 6
# 6
# 7
# 8
# 8
# Epoch 47 completed in 2.776 s, avgerage: 2.723 s, est. time left: 2.405 m
# 6
# 5
# 5
# 5
# 4
# 5
# 5
# 6
# 7
# 6
# 6
# 7
# Epoch 48 completed in 2.698 s, avgerage: 2.722 s, est. time left: 2.359 m
# 6
# 7
# 6
# 6
# 6
# 6
# 7
# 6
# 4
# 6
# 6
# 6
# Epoch 49 completed in 2.472 s, avgerage: 2.717 s, est. time left: 2.31 m
# 6
# 6
# 7
# 7
# 8
# 9
# 10
# 10
# 9
# 8
# 9
# 8
# Epoch 50 completed in 2.923 s, avgerage: 2.721 s, est. time left: 2.268 m
# 50 epochs left
# 6
# 7
# 7
# 8
# 7
# 7
# 7
# 7
# 6
# 7
# 7
# 7
# Epoch 51 completed in 2.777 s, avgerage: 2.722 s, est. time left: 2.223 m
# 6
# 6
# 6
# 7
# 7
# 6
# 6
# 6
# 6
# 5
# 5
# 6
# Epoch 52 completed in 2.704 s, avgerage: 2.722 s, est. time left: 2.178 m
# 6
# 7
# 8
# 9
# 9
# 10
# 10
# 9
# 9
# 8
# 8
# 8
# Epoch 53 completed in 3.022 s, avgerage: 2.728 s, est. time left: 2.137 m
# 6
# 6
# 6
# 6
# 6
# 6
# 7
# 7
# 7
# 8
# 9
# 10
# Epoch 54 completed in 2.608 s, avgerage: 2.726 s, est. time left: 2.089 m
# 6
# 6
# 6
# 7
# 8
# 7
# 8
# 7
# 7
# 6
# 6
# 7
# Epoch 55 completed in 2.725 s, avgerage: 2.726 s, est. time left: 2.044 m
# 6
# 6
# 5
# 5
# 6
# 7
# 7
# 6
# 6
# 7
# 7
# 6
# Epoch 56 completed in 2.642 s, avgerage: 2.724 s, est. time left: 1.997 m
# 6
# 7
# 7
# 6
# 6
# 6
# 8
# 8
# 7
# 8
# 7
# 8
# Epoch 57 completed in 2.451 s, avgerage: 2.719 s, est. time left: 1.949 m
# 6
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 7
# 8
# 7
# Epoch 58 completed in 2.746 s, avgerage: 2.72 s, est. time left: 1.904 m
# 6
# 6
# 6
# 6
# 7
# 8
# 8
# 7
# 6
# 7
# 8
# 7
# Epoch 59 completed in 2.6 s, avgerage: 2.718 s, est. time left: 1.857 m
# 6
# 7
# 6
# 7
# 6
# 6
# 6
# 7
# 8
# 8
# 8
# 9
# Epoch 60 completed in 2.776 s, avgerage: 2.719 s, est. time left: 1.812 m
# 40 epochs left
# 6
# 5
# 5
# 5
# 4
# 5
# 5
# 6
# 7
# 7
# 6
# 7
# Epoch 61 completed in 2.661 s, avgerage: 2.718 s, est. time left: 1.766 m
# 6
# 7
# 6
# 5
# 5
# 5
# 5
# 5
# 6
# 5
# 6
# 7
# Epoch 62 completed in 2.52 s, avgerage: 2.714 s, est. time left: 1.719 m
# 6
# 6
# 6
# 6
# 6
# 7
# 6
# 7
# 8
# 8
# 8
# 7
# Epoch 63 completed in 2.649 s, avgerage: 2.713 s, est. time left: 1.673 m
# 6
# 5
# 4
# 3
# 3
# 4
# 4
# 5
# 5
# 6
# 7
# 6
# Epoch 64 completed in 2.635 s, avgerage: 2.712 s, est. time left: 1.627 m
# 6
# 5
# 4
# 4
# 4
# 5
# 5
# 5
# 6
# 7
# 7
# 7
# Epoch 65 completed in 2.746 s, avgerage: 2.713 s, est. time left: 1.582 m
# 6
# 6
# 6
# 6
# 5
# 6
# 6
# 6
# 7
# 8
# 7
# 7
# Epoch 66 completed in 2.659 s, avgerage: 2.712 s, est. time left: 1.537 m
# 6
# 5
# 5
# 5
# 6
# 7
# 8
# 8
# 7
# 8
# 7
# 6
# Epoch 67 completed in 2.791 s, avgerage: 2.713 s, est. time left: 1.492 m
# 6
# 7
# 7
# 7
# 8
# 7
# 8
# 8
# 8
# 8
# 8
# 8
# Epoch 68 completed in 2.867 s, avgerage: 2.715 s, est. time left: 1.448 m
# 6
# 7
# 6
# 6
# 7
# 6
# 7
# 6
# 6
# 6
# 6
# 6
# Epoch 69 completed in 2.659 s, avgerage: 2.715 s, est. time left: 1.402 m
# 6
# 7
# 6
# 6
# 5
# 6
# 6
# 5
# 6
# 6
# 7
# 7
# Epoch 70 completed in 2.592 s, avgerage: 2.713 s, est. time left: 1.356 m
# 30 epochs left
# 6
# 7
# 6
# 5
# 6
# 6
# 6
# 7
# 5
# 6
# 6
# 7
# Epoch 71 completed in 2.591 s, avgerage: 2.711 s, est. time left: 1.31 m
# 6
# 6
# 6
# 7
# 7
# 6
# 7
# 7
# 7
# 8
# 8
# 8
# Epoch 72 completed in 2.812 s, avgerage: 2.713 s, est. time left: 1.266 m
# 6
# 7
# 6
# 6
# 5
# 5
# 5
# 5
# 5
# 5
# 4
# 5
# Epoch 73 completed in 2.608 s, avgerage: 2.711 s, est. time left: 1.22 m
# 6
# 7
# 6
# 7
# 7
# 9
# 8
# 8
# 9
# 10
# 11
# 11
# Epoch 74 completed in 2.712 s, avgerage: 2.711 s, est. time left: 1.175 m
# 6
# 7
# 6
# 6
# 7
# 7
# 8
# 7
# 8
# 7
# 8
# 8
# Epoch 75 completed in 2.733 s, avgerage: 2.711 s, est. time left: 1.13 m
# 6
# 6
# 7
# 7
# 7
# 7
# 7
# 8
# 8
# 7
# 7
# 7
# Epoch 76 completed in 2.708 s, avgerage: 2.711 s, est. time left: 1.084 m
# 6
# 6
# 7
# 6
# 5
# 6
# 7
# 6
# 5
# 6
# 5
# 6
# Epoch 77 completed in 2.664 s, avgerage: 2.711 s, est. time left: 1.039 m
# 6
# 7
# 6
# 6
# 7
# 7
# 6
# 7
# 7
# 7
# 6
# 7
# Epoch 78 completed in 2.727 s, avgerage: 2.711 s, est. time left: 0.994 m
# 6
# 7
# 7
# 7
# 6
# 6
# 6
# 6
# 6
# 7
# 7
# 5
# Epoch 79 completed in 2.651 s, avgerage: 2.71 s, est. time left: 0.948 m
# 6
# 5
# 6
# 6
# 6
# 6
# 6
# 7
# 7
# 8
# 7
# 8
# Epoch 80 completed in 2.901 s, avgerage: 2.713 s, est. time left: 0.904 m
# 20 epochs left
# 6
# 7
# 6
# 5
# 6
# 6
# 6
# 6
# 7
# 7
# 7
# 5
# Epoch 81 completed in 2.747 s, avgerage: 2.713 s, est. time left: 0.859 m
# 6
# 7
# 7
# 7
# 6
# 7
# 7
# 7
# 7
# 7
# 8
# 7
# Epoch 82 completed in 2.711 s, avgerage: 2.713 s, est. time left: 0.814 m
# 6
# 6
# 6
# 7
# 7
# 7
# 8
# 8
# 8
# 7
# 7
# 7
# Epoch 83 completed in 2.71 s, avgerage: 2.713 s, est. time left: 0.768 m
# 6
# 6
# 5
# 5
# 5
# 5
# 4
# 4
# 4
# 4
# 5
# 5
# Epoch 84 completed in 2.694 s, avgerage: 2.713 s, est. time left: 0.723 m
# 6
# 6
# 5
# 6
# 6
# 6
# 7
# 7
# 8
# 8
# 9
# 8
# Epoch 85 completed in 2.788 s, avgerage: 2.714 s, est. time left: 0.678 m
# 6
# 6
# 7
# 6
# 6
# 6
# 6
# 5
# 6
# 6
# 7
# 7
# 7
# Epoch 86 completed in 2.164 s, avgerage: 2.707 s, est. time left: 0.631 m
# 6
# 5
# 5
# 6
# 7
# 7
# 8
# 8
# 7
# 8
# 8
# 8
# Epoch 87 completed in 2.746 s, avgerage: 2.708 s, est. time left: 0.586 m
# 6
# 5
# 6
# 6
# 6
# 7
# 6
# 6
# 7
# 7
# 6
# 6
# Epoch 88 completed in 2.566 s, avgerage: 2.706 s, est. time left: 0.541 m
# 6
# 5
# 6
# 6
# 7
# 6
# 7
# 7
# 7
# 6
# 5
# 6
# Epoch 89 completed in 1.966 s, avgerage: 2.698 s, est. time left: 0.494 m
# 6
# 6
# 5
# 6
# 7
# 7
# 7
# 6
# 7
# 7
# 6
# 6
# Epoch 90 completed in 2.722 s, avgerage: 2.698 s, est. time left: 0.449 m
# 10 epochs left
# 6
# 7
# 7
# 6
# 7
# 7
# 7
# 8
# 8
# 7
# 7
# 8
# Epoch 91 completed in 2.843 s, avgerage: 2.7 s, est. time left: 0.405 m
# 6
# 5
# 6
# 7
# 8
# 7
# 8
# 9
# 10
# 11
# 10
# 9
# Epoch 92 completed in 2.911 s, avgerage: 2.702 s, est. time left: 0.36 m
# 6
# 5
# 5
# 5
# 6
# 7
# 6
# 5
# 6
# 7
# 6
# 6
# Epoch 93 completed in 2.202 s, avgerage: 2.696 s, est. time left: 0.314 m
# 6
# 5
# 4
# 4
# 5
# 5
# 4
# 4
# 4
# 4
# 3
# 4
# Epoch 94 completed in 2.387 s, avgerage: 2.693 s, est. time left: 0.269 m
# 6
# 7
# 7
# 7
# 8
# 7
# 6
# 7
# 8
# 9
# 10
# 9
# Epoch 95 completed in 2.773 s, avgerage: 2.694 s, est. time left: 0.224 m
# 6
# 6
# 7
# 8
# 8
# 7
# 7
# 7
# 8
# 8
# 7
# 8
# Epoch 96 completed in 2.754 s, avgerage: 2.695 s, est. time left: 0.179 m
# 6
# 7
# 7
# 6
# 6
# 6
# 7
# 7
# 8
# 7
# 7
# 8
# Epoch 97 completed in 2.706 s, avgerage: 2.695 s, est. time left: 0.134 m
# 6
# 7
# 7
# 7
# 7
# 6
# 7
# 7
# 6
# 5
# 6
# 6
# Epoch 98 completed in 2.531 s, avgerage: 2.693 s, est. time left: 0.089 m
# 6
# 5
# 6
# 7
# 7
# 7
# 7
# 7
# 7
# 6
# 6
# 7
# Epoch 99 completed in 2.763 s, avgerage: 2.694 s, est. time left: 0.045 m
# 6
# 6
# 7
# 7
# 7
# 7
# 8
# 6
# 8
# 9
# 10
# 10
# Epoch 100 completed in 2.828 s, avgerage: 2.695 s, est. time left: -0.0 m

# %%
plt.plot(ev_history['death_bomb'], label='death_bomb')
plt.plot(ev_history['death_monster'], label='death_monster')
plt.plot(ev_history['exited'], label='exited')
plt.legend()
plt.show()

plt.plot(ws_history['exit-distance'], label='exit-distance')
plt.plot(ws_history['monster-distance'], label='monster-distance')
plt.plot(ws_history['explosion-distance'], label='explosion-distance')
plt.legend()
plt.show()

print(f"{np.array(ev_history['exited'])[-1]}/{epochs} = {np.array(ev_history['exited'])[-1]/epochs}")
print(ours.weights)
# Out:
# 0/100 = 0.0
# Counter({'bomb_at': -67.24808151614926, 'exit-distance': -44731.81538096255, 'monster-distance': -129735.24850396744})
